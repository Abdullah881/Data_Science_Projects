# %%
import pandas as pd

# %%
data = 'Realestate.csv'

# %%
data
# Out:
# 'Realestate.csv'

# %%
data = pd.read_csv('Realestate.csv')

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1

# %%
data.dtypes
# use .dtypes to display data types
# Out:
# No                               int64
# transaction                    float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# numberOfConvenienceStores        int64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# dtype: object

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
#minmax = (houseAge - houseAge.min()) / (houseAge.max () - houseAge.min())

# %%
data.houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
#minmax = (height - height.min()) / (height.max () - height.min())

# %%
#minmax = (houseAge - houseAge.min()) / (houseAge.max() - houseAge.min())

# %%
houseAge = data.houseAge
houseAge
# load data from the colum into a variable
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
minmax = (houseAge - houseAge.min()) / (houseAge.max () - houseAge.min())
# using this formula we can normalise all the values into a range of 0 to 1

# %%
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
minmax.min()
minmax.max()
# Out:
# 1.0

# %%
minmax.min()
# Out:
# 0.0

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data.houseAge = minmax
# this loads the new normalised data into the data table

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917  0.730594                     84.87882
# 1      2     2012.917  0.445205                    306.59470
# 2      3     2013.583  0.303653                    561.98450
# 3      4     2013.500  0.303653                    561.98450
# 4      5     2012.833  0.114155                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000  0.312785                   4082.01500
# 414  411     2012.667  0.127854                     90.45606
# 415  412     2013.250  0.429224                    390.96960
# 416  413     2013.000  0.184932                    104.81010
# 417  414     2013.500  0.148402                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data = pd.read_csv('Realestate.csv')

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
houseAge = data.houseAge

# %%
minmax = (houseAge - houseAge.min()) / (houseAge.max () - houseAge.min())

# %%
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data['houseAgeStandardized'] = minmax
data
# this creates a new column and loads the normalised house age data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.drop(columns = ['houseAge'])
# Out:
#       No  transaction  distanceToNearestMRTstation  numberOfConvenienceStores  \
# 0      1     2012.917                     84.87882                         10
# 1      2     2012.917                    306.59470                          9
# 2      3     2013.583                    561.98450                          5
# 3      4     2013.500                    561.98450                          5
# 4      5     2012.833                    390.56840                          5
# ..   ...          ...                          ...                        ...
# 413  410     2013.000                   4082.01500                          0
# 414  411     2012.667                     90.45606                          9
# 415  412     2013.250                    390.96960                          7
# 416  413     2013.000                    104.81010                          5
# 417  414     2013.500                     90.45606                          9
#
# ...

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.drop(columns = ['numberOfConvenienceStores'])
#Delete the column numberOfConvenienceStores, 
#this doesnt change the orignal data table but generates and shows a new one
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.drop(columns = ['numberOfConvenienceStores'] , inplace = True)
#Delete the column numberOfConvenienceStores in our original data table

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.rename(columns={"transaction": "transactionDate"})
#change column name
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.loc[1]
# Out:
# No                                2.000000
# transaction                    2012.917000
# houseAge                         19.500000
# distanceToNearestMRTstation     306.594700
# latitude                         24.980340
# longitude                       121.539510
# housePriceOfUnitArea             42.200000
# houseAgeStandardized              0.445205
# Name: 1, dtype: float64

# %%
data.loc[0:10,:]
# Out:
#     No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1     2012.917      32.0                     84.87882  24.98298
# 1    2     2012.917      19.5                    306.59470  24.98034
# 2    3     2013.583      13.3                    561.98450  24.98746
# 3    4     2013.500      13.3                    561.98450  24.98746
# 4    5     2012.833       5.0                    390.56840  24.97937
# 5    6     2012.667       7.1                   2175.03000  24.96305
# 6    7     2012.667      34.5                    623.47310  24.97933
# 7    8     2013.417      20.3                    287.60250  24.98042
# 8    9     2013.500      31.7                   5512.03800  24.95095
# 9   10     2013.417      17.9                   1783.18000  24.96731
# 10  11     2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 0   121.54024                   NaN              0.730594
# ...

# %%
data.iloc[0:11,:]
# Out:
#     No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1     2012.917      32.0                     84.87882  24.98298
# 1    2     2012.917      19.5                    306.59470  24.98034
# 2    3     2013.583      13.3                    561.98450  24.98746
# 3    4     2013.500      13.3                    561.98450  24.98746
# 4    5     2012.833       5.0                    390.56840  24.97937
# 5    6     2012.667       7.1                   2175.03000  24.96305
# 6    7     2012.667      34.5                    623.47310  24.97933
# 7    8     2013.417      20.3                    287.60250  24.98042
# 8    9     2013.500      31.7                   5512.03800  24.95095
# 9   10     2013.417      17.9                   1783.18000  24.96731
# 10  11     2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 0   121.54024                   NaN              0.730594
# ...

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.loc[1]
# Out:
# No                                2.000000
# transaction                    2012.917000
# houseAge                         19.500000
# distanceToNearestMRTstation     306.594700
# latitude                         24.980340
# longitude                       121.539510
# housePriceOfUnitArea             42.200000
# houseAgeStandardized              0.445205
# Name: 1, dtype: float64

# %%
data.iloc[1]
# Out:
# No                                2.000000
# transaction                    2012.917000
# houseAge                         19.500000
# distanceToNearestMRTstation     306.594700
# latitude                         24.980340
# longitude                       121.539510
# housePriceOfUnitArea             42.200000
# houseAgeStandardized              0.445205
# Name: 1, dtype: float64

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
data.loc[data.duplicated()]
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 211  211     2013.500       5.2                     390.5684  24.97937
# 234  217     2013.250      37.8                     590.9292  24.97153
# 277  254     2012.667      30.4                    1735.5950  24.96464
# 302  299     2013.333      16.7                    4082.0150  24.94155
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# 211  121.54245                  52.2              0.118721
# 234  121.53559                  39.7              0.863014
# 277  121.51623                  25.9              0.694064
# 302  121.50381                  16.7              0.381279

# %%
data.drop_duplicates()
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
# Four Dupliactes Found

# %%
data.head
# Out:
# <bound method NDFrame.head of       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.housePriceOfUnitArea.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0       NaN
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 413    15.4
# 414    50.0
# 415    40.6
# 416    52.5
# 417    63.9
# Name: housePriceOfUnitArea, Length: 418, dtype: float64>

# %%
data['housePriceOfUnitArea'].mean()
# Out:
# 38.03373493975904

# %%
Mean = data['housePriceOfUnitArea'].mean()
# find mean of housing price

# %%
Mean
# Out:
# 38.03373493975904

# %%
data.isnull().any()
# are there any blank fields and where ( which column)
# Out:
# No                             False
# transaction                    False
# houseAge                       False
# distanceToNearestMRTstation    False
# latitude                       False
# longitude                      False
# housePriceOfUnitArea            True
# houseAgeStandardized           False
# dtype: bool

# %%
data[data.isnull().any(axis=1)]
# show rows which have empty fields
# Out:
#     No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1     2012.917      32.0                     84.87882  24.98298
# 27  28     2013.250      10.4                    276.44900  24.95593
# 37  38     2013.167      12.0                   1360.13900  24.95204
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 0   121.54024                   NaN              0.730594
# 27  121.53913                   NaN              0.237443
# 37  121.54842                   NaN              0.273973

# %%
data.fillna(Mean)
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.fillna(Mean , inplace = True)
# replace the empty fields with mean housing price

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.rename(columns={"transaction": "transactionDate"}, inplace = True)
#change column name in main table

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop_duplicates()
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data = data.drop_duplicates()
# drop duplicates in main table

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...
